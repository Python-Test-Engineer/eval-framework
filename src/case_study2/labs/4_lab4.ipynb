# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv, find_dotenv
import asyncio
import sendgrid
import os
from pathlib import Path

from typing import Dict
from IPython.display import display, Markdown
from rich.console import Console

# %%
console = Console()

# %%
load_dotenv(find_dotenv(), override=True)
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not set. Set OPENAI_API_KEY environment variable.")
else:
    console.print(
        f"OpenAI API Key exists and begins [dark_orange]{OPENAI_API_KEY[:14]}...[/]"
    )

# %% [markdown]
# ## OpenAI Hosted Tools
#
# OpenAI Agents SDK includes the following hosted tools:
#
# The `WebSearchTool` lets an agent search the web.
# The `FileSearchTool` allows retrieving information from your OpenAI Vector Stores.
# The `ComputerTool` allows automating computer use tasks like taking screenshots and clicking.
#
# ### Important note - API charge of WebSearchTool
#
# This is costing me 2.5 cents per call for OpenAI WebSearchTool. That can add up to $2-$3 for the next 2 labs. We'll use free and low cost Search tools with other platforms, so feel free to skip running this if the cost is a concern. Also student Christian W. pointed out that OpenAI can sometimes charge for multiple searches for a single call, so it could sometimes cost more than 2.5 cents per call.
#
# Costs are here: https://platform.openai.com/docs/pricing#web-search

# %%
INSTRUCTIONS = "You are a research assistant. Given a search term, you search the web for that term and \
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 \
words. Capture the main points. Write succintly, no need to have complete sentences or good \
grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the \
essence and ignore any fluff. Do not include any additional commentary other than the summary itself."

search_agent = Agent(
    name="Search agent",
    instructions=INSTRUCTIONS,
    tools=[WebSearchTool(search_context_size="low")],
    model="gpt-4o-mini",
    model_settings=ModelSettings(tool_choice="required"),
)

# %%
def inspect_run_result(run_result):
    print(f"Object type: {type(run_result)}")
    print(f"Object repr: {repr(run_result)}")

    # Get all public attributes (non-private)
    print("\nAll public attributes:")
    for attr_name in dir(run_result):
        if not attr_name.startswith("_"):
            try:
                attr_value = getattr(run_result, attr_name)
                if not callable(attr_value):  # Skip methods
                    print(f"  {attr_name}: {type(attr_value)} = {attr_value}")
                else:
                    print(f"  {attr_name}: <method>")
            except Exception as e:
                print(f"  {attr_name}: Error accessing - {e}")

    # Get __dict__ if available
    if hasattr(run_result, "__dict__"):
        print("\n__dict__ contents:")
        for key, value in run_result.__dict__.items():
            print(f"  {key}: {type(value)} = {value}")

# %%
message = "Latest AI Agent frameworks in 2025"

file_path = Path("output/log_search.csv")

if os.path.exists(file_path):
    print(f"✅ File exists: {file_path}")
    with trace("Search"):
        result = await Runner.run(search_agent, message)

        with open("output/log_search.csv", "a") as f:
            f.write(
                f"{gen_trace_id()}|{message}|{result.raw_responses}|{result.new_items}|{result.output_guardrail_results}\n"
            )
else:
    print(f"❌ File does not exist: {file_path}")
# Out:
# ✅ File exists: output\log_search.csv
# Object type: <class 'agents.result.RunResult'>
# Object repr: RunResult(input='Latest AI Agent frameworks in 2025', new_items=[ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860c7c3de881a1a0b227d2d87c752f013d0a73a125039f', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860c7ea4b481a18aa943fa5c4e86b9013d0a73a125039f', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=539, start_index=400, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=934, start_index=795, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1310, start_index=1171, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1761, start_index=1622, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2151, start_index=2012, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/ ...
#
# All public attributes:
#   context_wrapper: <class 'agents.run_context.RunContextWrapper'> = RunContextWrapper(context=None, usage=Usage(requests=1, input_tokens=407, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=606, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1013))
#   final_output: <class 'str'> = As of mid-2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems:
#
# - **AutoGen**: An open-source framework facilitating AI agent development with a focus on asynchronous messaging, modularity, and scalability. It supports cross-language interoperability and includes built-in tools for observability and debugging. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **CrewAI**: A lightweight Python framework emphasizing role-based agent design, enabling the creation of agents with distinct roles and capabilities. It supports intelligent collaboration, task management, and integration with external tools and APIs. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LangChain**: An open-source framework for building LLM-powered applications, including chatbots and AI agents. It offers a modular architecture, integration with APIs and databases, and supports chains, agents, and memory modules. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LangGraph**: An open-source framework for AI agents created by LangChain, facilitating the creation, deployment, and management of advanced generative AI workflows. It offers a robust set of tools and libraries to help users efficiently build, execute, and fine-tune large language models (LLMs) at scale. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LlamaIndex**: An open-source data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with newly added workflows that enable the development of multi-agent systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# Additionally, **Amazon Web Services (AWS)** introduced **Amazon Bedrock AgentCore**, a platform designed to simplify the development and deployment of advanced AI agents. AgentCore includes modular services supporting the full production lifecycle, such as scalable serverless deployment, context management, secure service access, tool integration, and enhanced problem-solving capabilities. This platform emphasizes flexibility, allowing developers to use only the components they need, facilitating scalable and secure AI agent development. ([techradar.com](https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai))
#
# These frameworks and platforms reflect the rapid evolution in AI agent development, offering diverse tools and capabilities to meet various application needs.
#   final_output_as: <method>
#   input: <class 'str'> = Latest AI Agent frameworks in 2025
#   input_guardrail_results: <class 'list'> = []
#   last_agent: <class 'agents.agent.Agent'> = Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)
#   last_response_id: <class 'str'> = resp_68860c7c30e081a1a7f85bd476823ede013d0a73a125039f
#   new_items: <class 'list'> = [ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860c7c3de881a1a0b227d2d87c752f013d0a73a125039f', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860c7ea4b481a18aa943fa5c4e86b9013d0a73a125039f', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=539, start_index=400, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=934, start_index=795, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1310, start_index=1171, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1761, start_index=1622, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2151, start_index=2012, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025- ...
#   output_guardrail_results: <class 'list'> = []
#   raw_responses: <class 'list'> = [ModelResponse(output=[ResponseFunctionWebSearch(id='ws_68860c7c3de881a1a0b227d2d87c752f013d0a73a125039f', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_68860c7ea4b481a18aa943fa5c4e86b9013d0a73a125039f', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=539, start_index=400, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=934, start_index=795, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1310, start_index=1171, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1761, start_index=1622, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2151, start_index=2012, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2829, start_index=2697, title='AWS looks to super-charge AI agents with Amazon Bedrock AgentCore', type='url_citation', url='https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai')], text='As of mid-2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems:\n\n- **AutoGen**: An open-source framework facilitating AI agent development with a focus on asynchronous messaging, modularity, and scalability. It supports cross-language interoperability and includes built-in tools for observability and debugging. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **CrewAI**: A lightweight Python framework emphasizing role-based agent design, enabling the creation of agents with distinct roles and capabilities. It supports intelligent collaboration, task management, and integration with external tools and APIs. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LangChain**: An open-source framework for building LLM-powered applications, including chatbots and AI agents. It offers a modular architecture, integration with APIs and databases, and supports chains, agents, and memory modules. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LangGraph**: An open-source framework for AI agents created by LangChain, facilitating the creation, deployment, and management of advanced generative AI workflows. It offers a robust set of tools and libraries to help users efficiently build, execute, and fine-tune large language models (LLMs) at scale. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LlamaIndex**: An open-source data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with newly added workflows that enable the development of multi-agent systems. ([antiersolutions.com](https://www.antiersolutions.co ...
#   to_input_list: <method>
#
# __dict__ contents:
#   input: <class 'str'> = Latest AI Agent frameworks in 2025
#   new_items: <class 'list'> = [ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860c7c3de881a1a0b227d2d87c752f013d0a73a125039f', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860c7ea4b481a18aa943fa5c4e86b9013d0a73a125039f', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=539, start_index=400, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=934, start_index=795, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1310, start_index=1171, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1761, start_index=1622, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2151, start_index=2012, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025- ...
#   raw_responses: <class 'list'> = [ModelResponse(output=[ResponseFunctionWebSearch(id='ws_68860c7c3de881a1a0b227d2d87c752f013d0a73a125039f', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_68860c7ea4b481a18aa943fa5c4e86b9013d0a73a125039f', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=539, start_index=400, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=934, start_index=795, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1310, start_index=1171, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1761, start_index=1622, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2151, start_index=2012, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2829, start_index=2697, title='AWS looks to super-charge AI agents with Amazon Bedrock AgentCore', type='url_citation', url='https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai')], text='As of mid-2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems:\n\n- **AutoGen**: An open-source framework facilitating AI agent development with a focus on asynchronous messaging, modularity, and scalability. It supports cross-language interoperability and includes built-in tools for observability and debugging. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **CrewAI**: A lightweight Python framework emphasizing role-based agent design, enabling the creation of agents with distinct roles and capabilities. It supports intelligent collaboration, task management, and integration with external tools and APIs. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LangChain**: An open-source framework for building LLM-powered applications, including chatbots and AI agents. It offers a modular architecture, integration with APIs and databases, and supports chains, agents, and memory modules. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LangGraph**: An open-source framework for AI agents created by LangChain, facilitating the creation, deployment, and management of advanced generative AI workflows. It offers a robust set of tools and libraries to help users efficiently build, execute, and fine-tune large language models (LLMs) at scale. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n- **LlamaIndex**: An open-source data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with newly added workflows that enable the development of multi-agent systems. ([antiersolutions.com](https://www.antiersolutions.co ...
#   final_output: <class 'str'> = As of mid-2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems:
#
# - **AutoGen**: An open-source framework facilitating AI agent development with a focus on asynchronous messaging, modularity, and scalability. It supports cross-language interoperability and includes built-in tools for observability and debugging. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **CrewAI**: A lightweight Python framework emphasizing role-based agent design, enabling the creation of agents with distinct roles and capabilities. It supports intelligent collaboration, task management, and integration with external tools and APIs. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LangChain**: An open-source framework for building LLM-powered applications, including chatbots and AI agents. It offers a modular architecture, integration with APIs and databases, and supports chains, agents, and memory modules. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LangGraph**: An open-source framework for AI agents created by LangChain, facilitating the creation, deployment, and management of advanced generative AI workflows. It offers a robust set of tools and libraries to help users efficiently build, execute, and fine-tune large language models (LLMs) at scale. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# - **LlamaIndex**: An open-source data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with newly added workflows that enable the development of multi-agent systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# Additionally, **Amazon Web Services (AWS)** introduced **Amazon Bedrock AgentCore**, a platform designed to simplify the development and deployment of advanced AI agents. AgentCore includes modular services supporting the full production lifecycle, such as scalable serverless deployment, context management, secure service access, tool integration, and enhanced problem-solving capabilities. This platform emphasizes flexibility, allowing developers to use only the components they need, facilitating scalable and secure AI agent development. ([techradar.com](https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai))
#
# These frameworks and platforms reflect the rapid evolution in AI agent development, offering diverse tools and capabilities to meet various application needs.
#   input_guardrail_results: <class 'list'> = []
#   output_guardrail_results: <class 'list'> = []
#   context_wrapper: <class 'agents.run_context.RunContextWrapper'> = RunContextWrapper(context=None, usage=Usage(requests=1, input_tokens=407, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=606, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1013))
#   _last_agent: <class 'agents.agent.Agent'> = Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)
# None

# %%
# Out:
# RunResult attributes:
# Object type: <class 'agents.result.RunResult'>
# Object repr: RunResult(input='Latest AI Agent frameworks in 2025', new_items=[ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860a4218c48191aa06107c1a026551070c9723cd5aa8e0', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860a4424a88191b3b80655381cf149070c9723cd5aa8e0', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=527, start_index=388, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=926, start_index=787, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1345, start_index=1206, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1786, start_index=1647, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2206, start_index=2067, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/ ...
#
# All public attributes:
#   context_wrapper: <class 'agents.run_context.RunContextWrapper'> = RunContextWrapper(context=None, usage=Usage(requests=1, input_tokens=407, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=551, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=958))
#   final_output: <class 'str'> = In 2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems.
#
# **AutoGen** is an open-source framework designed to simplify collaboration among multiple agents. It features asynchronous messaging, modular extensibility, and robust observability tools, facilitating scalable and distributed agent networks. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **CrewAI** focuses on role-based agent design, enabling the creation of agents with distinct roles and capabilities. Its lightweight architecture ensures high execution speed and developer control, making it suitable for complex, enterprise-grade AI agents. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LangChain** offers a modular architecture for building LLM-powered applications, including chatbots and AI agents. It supports integration with APIs and databases, and includes tools for adding memory to applications, facilitating the development of context-aware AI systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LangGraph** is an open-source framework that enables the creation, deployment, and management of advanced generative AI workflows. It leverages a graph-based architecture to represent complex interconnections within AI agent workflows, supporting stateful applications and dynamic decision-making. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LlamaIndex** is a data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with workflows that enable the development of multi-agent systems, streamlining context augmentation for GenAI use cases. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# Additionally, **Amazon Web Services (AWS)** introduced **Amazon Bedrock AgentCore**, a platform designed to simplify the development and deployment of advanced AI agents. It includes modular services supporting the full production lifecycle, emphasizing flexibility and scalability. ([techradar.com](https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai))
#
# These frameworks and platforms reflect the rapid evolution of AI agent development, offering diverse tools to meet various application needs.
#   final_output_as: <method>
#   input: <class 'str'> = Latest AI Agent frameworks in 2025
#   input_guardrail_results: <class 'list'> = []
#   last_agent: <class 'agents.agent.Agent'> = Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)
#   last_response_id: <class 'str'> = resp_68860a420668819193d35376a2b4fc76070c9723cd5aa8e0
#   new_items: <class 'list'> = [ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860a4218c48191aa06107c1a026551070c9723cd5aa8e0', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860a4424a88191b3b80655381cf149070c9723cd5aa8e0', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=527, start_index=388, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=926, start_index=787, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1345, start_index=1206, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1786, start_index=1647, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2206, start_index=2067, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025- ...
#   output_guardrail_results: <class 'list'> = []
#   raw_responses: <class 'list'> = [ModelResponse(output=[ResponseFunctionWebSearch(id='ws_68860a4218c48191aa06107c1a026551070c9723cd5aa8e0', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_68860a4424a88191b3b80655381cf149070c9723cd5aa8e0', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=527, start_index=388, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=926, start_index=787, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1345, start_index=1206, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1786, start_index=1647, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2206, start_index=2067, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2623, start_index=2491, title='AWS looks to super-charge AI agents with Amazon Bedrock AgentCore', type='url_citation', url='https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai')], text='In 2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems.\n\n**AutoGen** is an open-source framework designed to simplify collaboration among multiple agents. It features asynchronous messaging, modular extensibility, and robust observability tools, facilitating scalable and distributed agent networks. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**CrewAI** focuses on role-based agent design, enabling the creation of agents with distinct roles and capabilities. Its lightweight architecture ensures high execution speed and developer control, making it suitable for complex, enterprise-grade AI agents. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LangChain** offers a modular architecture for building LLM-powered applications, including chatbots and AI agents. It supports integration with APIs and databases, and includes tools for adding memory to applications, facilitating the development of context-aware AI systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LangGraph** is an open-source framework that enables the creation, deployment, and management of advanced generative AI workflows. It leverages a graph-based architecture to represent complex interconnections within AI agent workflows, supporting stateful applications and dynamic decision-making. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LlamaIndex** is a data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with workflows that enable the development of multi-agent systems, streamlining context augmentation for GenAI use cases ...
#   to_input_list: <method>
#
# __dict__ contents:
#   input: <class 'str'> = Latest AI Agent frameworks in 2025
#   new_items: <class 'list'> = [ToolCallItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseFunctionWebSearch(id='ws_68860a4218c48191aa06107c1a026551070c9723cd5aa8e0', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), type='tool_call_item'), MessageOutputItem(agent=Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True), raw_item=ResponseOutputMessage(id='msg_68860a4424a88191b3b80655381cf149070c9723cd5aa8e0', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=527, start_index=388, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=926, start_index=787, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1345, start_index=1206, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1786, start_index=1647, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2206, start_index=2067, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025- ...
#   raw_responses: <class 'list'> = [ModelResponse(output=[ResponseFunctionWebSearch(id='ws_68860a4218c48191aa06107c1a026551070c9723cd5aa8e0', action=ActionSearch(query='Latest AI Agent frameworks in 2025', type='search'), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_68860a4424a88191b3b80655381cf149070c9723cd5aa8e0', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=527, start_index=388, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=926, start_index=787, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1345, start_index=1206, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=1786, start_index=1647, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2206, start_index=2067, title='Top AI Agent Frameworks to Explore in 2025', type='url_citation', url='https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai'), AnnotationURLCitation(end_index=2623, start_index=2491, title='AWS looks to super-charge AI agents with Amazon Bedrock AgentCore', type='url_citation', url='https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai')], text='In 2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems.\n\n**AutoGen** is an open-source framework designed to simplify collaboration among multiple agents. It features asynchronous messaging, modular extensibility, and robust observability tools, facilitating scalable and distributed agent networks. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**CrewAI** focuses on role-based agent design, enabling the creation of agents with distinct roles and capabilities. Its lightweight architecture ensures high execution speed and developer control, making it suitable for complex, enterprise-grade AI agents. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LangChain** offers a modular architecture for building LLM-powered applications, including chatbots and AI agents. It supports integration with APIs and databases, and includes tools for adding memory to applications, facilitating the development of context-aware AI systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LangGraph** is an open-source framework that enables the creation, deployment, and management of advanced generative AI workflows. It leverages a graph-based architecture to represent complex interconnections within AI agent workflows, supporting stateful applications and dynamic decision-making. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))\n\n**LlamaIndex** is a data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with workflows that enable the development of multi-agent systems, streamlining context augmentation for GenAI use cases ...
#   final_output: <class 'str'> = In 2025, several AI agent frameworks have emerged, each offering unique features to enhance the development of intelligent, autonomous systems.
#
# **AutoGen** is an open-source framework designed to simplify collaboration among multiple agents. It features asynchronous messaging, modular extensibility, and robust observability tools, facilitating scalable and distributed agent networks. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **CrewAI** focuses on role-based agent design, enabling the creation of agents with distinct roles and capabilities. Its lightweight architecture ensures high execution speed and developer control, making it suitable for complex, enterprise-grade AI agents. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LangChain** offers a modular architecture for building LLM-powered applications, including chatbots and AI agents. It supports integration with APIs and databases, and includes tools for adding memory to applications, facilitating the development of context-aware AI systems. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LangGraph** is an open-source framework that enables the creation, deployment, and management of advanced generative AI workflows. It leverages a graph-based architecture to represent complex interconnections within AI agent workflows, supporting stateful applications and dynamic decision-making. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# **LlamaIndex** is a data orchestration framework ideal for developing generative AI and AI agent solutions. It features ready-to-use agents and tools, along with workflows that enable the development of multi-agent systems, streamlining context augmentation for GenAI use cases. ([antiersolutions.com](https://www.antiersolutions.com/blogs/top-ai-agent-frameworks-to-watch-in-2025-a-complete-guide/?utm_source=openai))
#
# Additionally, **Amazon Web Services (AWS)** introduced **Amazon Bedrock AgentCore**, a platform designed to simplify the development and deployment of advanced AI agents. It includes modular services supporting the full production lifecycle, emphasizing flexibility and scalability. ([techradar.com](https://www.techradar.com/pro/aws-looks-to-super-charge-ai-agents-with-amazon-bedrock-agentcore?utm_source=openai))
#
# These frameworks and platforms reflect the rapid evolution of AI agent development, offering diverse tools to meet various application needs.
#   input_guardrail_results: <class 'list'> = []
#   output_guardrail_results: <class 'list'> = []
#   context_wrapper: <class 'agents.run_context.RunContextWrapper'> = RunContextWrapper(context=None, usage=Usage(requests=1, input_tokens=407, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=551, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=958))
#   _last_agent: <class 'agents.agent.Agent'> = Agent(name='Search agent', instructions="You are a research assistant. Given a search term, you search the web for that term and produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 words. Capture the main points. Write succintly, no need to have complete sentences or good grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the essence and ignore any fluff. Do not include any additional commentary other than the summary itself.", prompt=None, handoff_description=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice='required', parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[WebSearchTool(user_location=None, search_context_size='low')], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
display(Markdown(result.final_output))

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ### We will now use Structured Outputs, and include a description of the fields

# %%
# See note above about cost of WebSearchTool

HOW_MANY_SEARCHES = 3

INSTRUCTIONS = f"You are a helpful research assistant. Given a query, come up with a set of web searches \
to perform to best answer the query. Output {HOW_MANY_SEARCHES} terms to query for."

# Use Pydantic to define the Schema of our response - this is known as "Structured Outputs"
# With massive thanks to student Wes C. for discovering and fixing a nasty bug with this!


class WebSearchItem(BaseModel):
    reason: str = Field(
        description="Your reasoning for why this search is important to the query."
    )

    query: str = Field(description="The search term to use for the web search.")


class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem] = Field(
        description="A list of web searches to perform to best answer the query."
    )


planner_agent = Agent(
    name="PlannerAgent",
    instructions=INSTRUCTIONS,
    model="gpt-4o-mini",
    output_type=WebSearchPlan,
)

# %%
message = "Latest AI Agent frameworks in 2025"

with trace("Search"):
    result = await Runner.run(planner_agent, message)
    print(result.final_output)

# %%
@function_tool
def send_email(subject: str, html_body: str) -> Dict[str, str]:
    """Send out an email with the given subject and HTML body"""
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get("SENDGRID_API_KEY"))
    from_email = Email("ed@edwarddonner.com")  # Change this to your verified email
    to_email = To("ed.donner@gmail.com")  # Change this to your email
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    response = sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
send_email

# %%
INSTRUCTIONS = """You are able to send a nicely formatted HTML email based on a detailed report.
You will be provided with a detailed report. You should use your tool to send one email, providing the 
report converted into clean, well presented HTML with an appropriate subject line."""

email_agent = Agent(
    name="Email agent",
    instructions=INSTRUCTIONS,
    tools=[send_email],
    model="gpt-4o-mini",
)

# %%
INSTRUCTIONS = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words."
)


class ReportData(BaseModel):
    short_summary: str = Field(
        description="A short 2-3 sentence summary of the findings."
    )

    markdown_report: str = Field(description="The final report")

    follow_up_questions: list[str] = Field(
        description="Suggested topics to research further"
    )


writer_agent = Agent(
    name="WriterAgent",
    instructions=INSTRUCTIONS,
    model="gpt-4o-mini",
    output_type=ReportData,
)

# %% [markdown]
# ### The next 3 functions will plan and execute the search, using planner_agent and search_agent

# %%
async def plan_searches(query: str):
    """Use the planner_agent to plan which searches to run for the query"""
    print("Planning searches...")
    result = await Runner.run(planner_agent, f"Query: {query}")
    print(f"Will perform {len(result.final_output.searches)} searches")
    return result.final_output


async def perform_searches(search_plan: WebSearchPlan):
    """Call search() for each item in the search plan"""
    print("Searching...")
    tasks = [asyncio.create_task(search(item)) for item in search_plan.searches]
    results = await asyncio.gather(*tasks)
    print("Finished searching")
    return results


async def search(item: WebSearchItem):
    """Use the search agent to run a web search for each item in the search plan"""
    input = f"Search term: {item.query}\nReason for searching: {item.reason}"
    result = await Runner.run(search_agent, input)
    return result.final_output

# %% [markdown]
# ### The next 2 functions write a report and email it

# %%
async def write_report(query: str, search_results: list[str]):
    """Use the writer agent to write a report based on the search results"""
    print("Thinking about report...")
    input = f"Original query: {query}\nSummarized search results: {search_results}"
    result = await Runner.run(writer_agent, input)
    print("Finished writing report")
    return result.final_output


async def send_email(report: ReportData):
    """Use the email agent to send an email with the report"""
    print("Writing email...")
    result = await Runner.run(email_agent, report.markdown_report)
    print("Email sent")
    return report

# %% [markdown]
# ### Showtime!

# %%
query = "Latest AI Agent frameworks in 2025"

with trace("Research trace"):
    print("Starting research...")
    search_plan = await plan_searches(query)
    search_results = await perform_searches(search_plan)
    report = await write_report(query, search_results)
    await send_email(report)
    print("Hooray!")

# %% [markdown]
# ### As always, take a look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thanks.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00cc00;">Congratulations on your progress, and a request</h2>
#             <span style="color:#00cc00;">You've reached an important moment with the course; you've created a valuable Agent using one of the latest Agent frameworks. You've upskilled, and unlocked new commercial possibilities. Take a moment to celebrate your success!<br/><br/>Something I should ask you -- my editor would smack me if I didn't mention this. If you're able to rate the course on Udemy, I'd be seriously grateful: it's the most important way that Udemy decides whether to show the course to others and it makes a massive difference.<br/><br/>And another reminder to <a href="https://www.linkedin.com/in/eddonner/">connect with me on LinkedIn</a> if you wish! If you wanted to post about your progress on the course, please tag me and I'll weigh in to increase your exposure.
#             </span>
#         </td>
#     </tr>
